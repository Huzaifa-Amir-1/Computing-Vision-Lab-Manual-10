# %%
# Code Example: Real-Time Object Detection for Smart Traffic Surveillance System
from ultralytics import YOLO 
import cv2 
import matplotlib.pyplot as plt 
model = YOLO('yolov8n.pt') 
image_path = "D:/BS AI/6th Semester/Mids/Computing Vision Lab/Lab Tasks/23108125/M19.jpg" 
image = cv2.imread(image_path) 
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) 
results = model(image_path) 
results[0].plot()
plt.figure(figsize=(12, 8)) 
plt.imshow(results[0].plot()[..., ::-1]) 
plt.axis('off') 
plt.title("Object Detection using YOLOv8") 
plt.show()
# Out:
# image 1/1 D:\BS AI\6th Semester\Mids\Computing Vision Lab\Lab Tasks\23108125\M19.jpg: 352x640 9 cars, 1 bus, 3 trucks, 149.4ms
# Speed: 7.0ms preprocess, 149.4ms inference, 10.8ms postprocess per image at shape (1, 3, 352, 640)

# %%
# Case Study 1: Real-Time Surveillance Analysis in Public Parks
import cv2 
from ultralytics import YOLO 
model = YOLO("yolov8n.pt") 
results = model("D:/BS AI/6th Semester/Mids/Computing Vision Lab/Lab Tasks/23108125/M16.jpg") 
import matplotlib.pyplot as plt 
import cv2 
img = results[0].plot()
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
plt.imshow(img_rgb)
plt.axis("off") 
plt.show()
# Out:
# image 1/1 D:\BS AI\6th Semester\Mids\Computing Vision Lab\Lab Tasks\23108125\M16.jpg: 416x640 1 person, 95.0ms
# Speed: 4.7ms preprocess, 95.0ms inference, 1.3ms postprocess per image at shape (1, 3, 416, 640)

# %%
# Object Detection Using SSD
from ultralytics import YOLO
import cv2
from moviepy.editor import VideoFileClip
model = YOLO("yolov8n.pt")
video_path = "D:/BS AI/6th Semester/Mids/Computing Vision Lab/Lab Tasks/23108125/Lecture M.mp4"
cap = cv2.VideoCapture(video_path)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 640)
out = cv2.VideoWriter(
    "output.mp4",
    cv2.VideoWriter_fourcc(*'mp4v'),
    5,
    (640, 640)
)
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    frame = cv2.resize(frame, (640, 640))
    results = model.predict(frame, imgsz=640, conf=0.5, verbose=False)
    annotated_frame = results[0].plot()
    out.write(annotated_frame)
cap.release()
out.release()
print("Video saved as output.mp4")
clip = VideoFileClip("output.mp4")
clip.write_gif("output.gif")
print("GIF saved as output.gif")
# Out:
# Video saved as output.mp4
# MoviePy - Building file output.gif with imageio.
# GIF saved as output.gif

# %%
# Case Study 2: Retail Checkout Automation
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
model = YOLO('yolov8n.pt')
image_path = "D:/BS AI/6th Semester/Mids/Computing Vision Lab/Lab Tasks/23108125/M22.jpg"
image = cv2.imread(image_path)
results = model(image_path)
annotated_img = results[0].plot()
img_rgb = cv2.cvtColor(annotated_img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(12, 8))
plt.imshow(img_rgb)
plt.axis('off')
plt.title("Smart Retail Checkout System using YOLOv8")
plt.show()
# Out:
# image 1/1 D:\BS AI\6th Semester\Mids\Computing Vision Lab\Lab Tasks\23108125\M22.jpg: 384x640 8 persons, 4 tvs, 103.7ms
# Speed: 3.4ms preprocess, 103.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Case Study 1: Smart Classroom Monitoring
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
model = YOLO("yolov8n.pt")
image_path = "D:/BS AI/6th Semester/Mids/Computing Vision Lab/Lab Tasks/23108125/M22.jpg"
image = cv2.imread(image_path)
results = model(image_path)
annotated = results[0].plot()
img_rgb = cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 6))
plt.imshow(img_rgb)
plt.axis("off")
plt.title("Smart Classroom Monitoring")
plt.show()
# Out:
# image 1/1 D:\BS AI\6th Semester\Mids\Computing Vision Lab\Lab Tasks\23108125\M22.jpg: 384x640 8 persons, 4 tvs, 77.1ms
# Speed: 4.9ms preprocess, 77.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)

# %%
#Case Study 2: Smart Parking Surveillance System
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
model = YOLO("yolov8n.pt")
image_path = "D:/BS AI/6th Semester/Mids/Computing Vision Lab/Lab Tasks/23108125/M19.jpg"
image = cv2.imread(image_path)
results = model(image_path)
annotated = results[0].plot()
img_rgb = cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 6))
plt.imshow(img_rgb)
plt.axis("off")
plt.title("Smart Parking Surveillance")
plt.show()
# Out:
# image 1/1 D:\BS AI\6th Semester\Mids\Computing Vision Lab\Lab Tasks\23108125\M19.jpg: 352x640 9 cars, 1 bus, 3 trucks, 74.0ms
# Speed: 3.0ms preprocess, 74.0ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)

# %%
# Case Study 3: Wildlife Conservation Monitoring
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
model = YOLO("yolov8n.pt")
image_path = "D:/BS AI/6th Semester/Mids/Computing Vision Lab/Lab Tasks/23108125/M29.jpg"
image = cv2.imread(image_path)
results = model(image_path)
annotated = results[0].plot()
img_rgb = cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 6))
plt.imshow(img_rgb)
plt.axis("off")
plt.title("Wildlife Conservation Monitoring")
plt.show()
# Out:
# image 1/1 D:\BS AI\6th Semester\Mids\Computing Vision Lab\Lab Tasks\23108125\M29.jpg: 384x640 1 cat, 83.0ms
# Speed: 2.9ms preprocess, 83.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Case Study 4: Industrial Defect Detection System
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
model = YOLO("yolov8n.pt")
image_path = "D:/BS AI/6th Semester/Mids/Computing Vision Lab/Lab Tasks/23108125/M21.jpg"
image = cv2.imread(image_path)
results = model(image_path)
annotated = results[0].plot()
img_rgb = cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 6))
plt.imshow(img_rgb)
plt.axis("off")
plt.title("Industrial Defect Detection")
plt.show()
# Out:
# image 1/1 D:\BS AI\6th Semester\Mids\Computing Vision Lab\Lab Tasks\23108125\M21.jpg: 640x640 (no detections), 111.1ms
# Speed: 9.1ms preprocess, 111.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
# Case Study 5: Retail Store Analytics with Shelf Monitoring
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
from collections import Counter
model = YOLO("yolov8n.pt")
image_path = "D:/BS AI/6th Semester/Mids/Computing Vision Lab/Lab Tasks/23108125/M9.jpg"
image = cv2.imread(image_path)
results = model(image_path)
annotated = results[0].plot()
items = []
for r in results:
    for box in r.boxes:
        cls = int(box.cls[0])
        items.append(model.names[cls])
count = Counter(items)
print("Shelf Inventory:")
for item, qty in count.items():
    print(item, ":", qty)
img_rgb = cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10, 6))
plt.imshow(img_rgb)
plt.axis("off")
plt.title("Retail Shelf Monitoring")
plt.show()
# Out:
# image 1/1 D:\BS AI\6th Semester\Mids\Computing Vision Lab\Lab Tasks\23108125\M9.jpg: 480x640 11 persons, 2 cars, 97.9ms
# Speed: 4.8ms preprocess, 97.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# Shelf Inventory:
# person : 11
# car : 2
